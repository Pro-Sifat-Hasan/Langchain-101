# %% [markdown]
# # Document Splitting

# %% [markdown]
# ## RecursiveCharacterTextSplitter

# %% [markdown]
# RecursiveCharacterTextSplitter হলো LangChain এর একটি টুল যা দীর্ঘ টেক্সটকে ছোট, পরিচালনাযোগ্য অংশে ভাগ করার জন্য ব্যবহৃত হয়। এটি বিশেষভাবে কার্যকর যখন বড় ডকুমেন্টগুলি প্রক্রিয়া করতে হয়, যেগুলি ভাষা মডেলগুলির দ্বারা পরিচালিত হতে পারে, যাদের একটি নির্দিষ্ট সংখ্যক টোকেনের সীমা থাকে।

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# chunk_size:
# chunk_size হল প্রতিটি টুকরো বা অংশে সর্বাধিক অক্ষরের সংখ্যা। উদাহরণস্বরূপ, যদি আপনি chunk_size ৫০০ নির্ধারণ করেন, তাহলে প্রতিটি অংশে সর্বাধিক ৫০০টি অক্ষর থাকবে। এটি আপনাকে দীর্ঘ টেক্সটকে ছোট ছোট অংশে ভেঙে বড় ডকুমেন্টগুলোকে সহজে প্রক্রিয়াজাত করার সুযোগ দেয়।
#
# chunk_overlap:
# chunk_overlap হল প্রতিটি অংশের মধ্যে কতগুলি অক্ষর ওভারল্যাপ করবে বা একের সাথে অন্যটি মিলিত থাকবে। উদাহরণস্বরূপ, যদি আপনি chunk_overlap ৫০ নির্ধারণ করেন, তাহলে প্রতিটি পরবর্তী অংশ পূর্ববর্তী অংশের শেষ ৫০টি অক্ষরের সাথে ওভারল্যাপ করবে। এটি অংশগুলির মধ্যে ধারাবাহিকতা বজায় রাখতে সাহায্য করে, যাতে এক অংশের শেষে এবং পরবর্তী অংশের শুরুতে থাকা বিষয়বস্তু সংযুক্ত থাকে।

# %% [markdown]
# Note: RecursiveCharacterTextSplitter এ chunk_overlap হয় না।

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,       # প্রতিটি অংশে সর্বাধিক অক্ষরের সংখ্যা
    chunk_overlap=50      # অংশগুলির মধ্যে ওভারল্যাপ করা অক্ষরের সংখ্যা
)

# %%
long_text = """
কৃত্রিম বুদ্ধিমত্তা (AI) হলো যন্ত্রগুলিতে মানুষের বুদ্ধিমত্তার অনুকরণ যা মানুষ হিসাবে চিন্তা করতে এবং তাদের কর্মগুলি অনুকরণ করতে প্রোগ্রাম করা হয়েছে।
এই শব্দটি যেকোন যন্ত্রের ক্ষেত্রে প্রযোজ্য হতে পারে যা মানুষের মনের সাথে সম্পর্কিত বৈশিষ্ট্যগুলি প্রদর্শন করে যেমন শেখা এবং সমস্যার সমাধান করা।
কৃত্রিম বুদ্ধিমত্তার আদর্শ বৈশিষ্ট্য হল এর যৌক্তিক করার ক্ষমতা এবং নির্দিষ্ট লক্ষ্য অর্জনের সর্বোত্তম সুযোগের সাথে কাজ করা।
কৃত্রিম বুদ্ধিমত্তার একটি উপসেট হল মেশিন লার্নিং (ML), যা নির্দেশ করে যে কম্পিউটার প্রোগ্রামগুলি স্বয়ংক্রিয়ভাবে নতুন ডেটা থেকে শেখার এবং অভিযোজিত হতে পারে।
গভীর শিক্ষার কৌশলগুলি টেক্সট, চিত্র বা ভিডিওর মতো বিশাল পরিমাণ অনিয়ন্ত্রিত ডেটার শোষণের মাধ্যমে এই স্বয়ংক্রিয় শিক্ষাকে সক্ষম করে।
"""

# %%
chunks = text_splitter.split_text(long_text)

# %%
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}:\n{chunk}\n")
# Out:
# Chunk 1:
# কৃত্রিম বুদ্ধিমত্তা (AI) হলো যন্ত্রগুলিতে মানুষের বুদ্ধিমত্তার অনুকরণ যা মানুষ হিসাবে চিন্তা করতে এবং তাদের কর্মগুলি অনুকরণ করতে প্রোগ্রাম করা হয়েছে।
# এই শব্দটি যেকোন যন্ত্রের ক্ষেত্রে প্রযোজ্য হতে পারে যা মানুষের মনের সাথে সম্পর্কিত বৈশিষ্ট্যগুলি প্রদর্শন করে যেমন শেখা এবং সমস্যার সমাধান করা।
# কৃত্রিম বুদ্ধিমত্তার আদর্শ বৈশিষ্ট্য হল এর যৌক্তিক করার ক্ষমতা এবং নির্দিষ্ট লক্ষ্য অর্জনের সর্বোত্তম সুযোগের সাথে কাজ করা।
#
# Chunk 2:
# কৃত্রিম বুদ্ধিমত্তার একটি উপসেট হল মেশিন লার্নিং (ML), যা নির্দেশ করে যে কম্পিউটার প্রোগ্রামগুলি স্বয়ংক্রিয়ভাবে নতুন ডেটা থেকে শেখার এবং অভিযোজিত হতে পারে।
# গভীর শিক্ষার কৌশলগুলি টেক্সট, চিত্র বা ভিডিওর মতো বিশাল পরিমাণ অনিয়ন্ত্রিত ডেটার শোষণের মাধ্যমে এই স্বয়ংক্রিয় শিক্ষাকে সক্ষম করে।

# %% [markdown]
# ## CharacterTextSplitter

# %%
from langchain.text_splitter import CharacterTextSplitter

# %%
# CharacterTextSplitter ইনিশিয়ালাইজ করা
text_splitter = CharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=50
)

# %%
long_text = """
কৃত্রিম বুদ্ধিমত্তা (AI) হলো যন্ত্রগুলিতে মানুষের বুদ্ধিমত্তার অনুকরণ যা মানুষ হিসাবে চিন্তা করতে এবং তাদের কর্মগুলি অনুকরণ করতে প্রোগ্রাম করা হয়েছে।
এই শব্দটি যেকোন যন্ত্রের ক্ষেত্রে প্রযোজ্য হতে পারে যা মানুষের মনের সাথে সম্পর্কিত বৈশিষ্ট্যগুলি প্রদর্শন করে যেমন শেখা এবং সমস্যার সমাধান করা।
কৃত্রিম বুদ্ধিমত্তার আদর্শ বৈশিষ্ট্য হল এর যৌক্তিক করার ক্ষমতা এবং নির্দিষ্ট লক্ষ্য অর্জনের সর্বোত্তম সুযোগের সাথে কাজ করা।
কৃত্রিম বুদ্ধিমত্তার একটি উপসেট হল মেশিন লার্নিং (ML), যা নির্দেশ করে যে কম্পিউটার প্রোগ্রামগুলি স্বয়ংক্রিয়ভাবে নতুন ডেটা থেকে শেখার এবং অভিযোজিত হতে পারে।
গভীর শিক্ষার কৌশলগুলি টেক্সট, চিত্র বা ভিডিওর মতো বিশাল পরিমাণ অনিয়ন্ত্রিত ডেটার শোষণের মাধ্যমে এই স্বয়ংক্রিয় শিক্ষাকে সক্ষম করে।
"""

# %%
chunks = text_splitter.split_text(long_text)

# %%
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}:\n{chunk}\n")
# Out:
# Chunk 1:
# কৃত্রিম বুদ্ধিমত্তা (AI) হলো যন্ত্রগুলিতে মানুষের বুদ্ধিমত্তার অনুকরণ যা মানুষ হিসাবে চিন্তা করতে এবং তাদের কর্মগুলি অনুকরণ করতে প্রোগ্রাম করা হয়েছে।
# এই শব্দটি যেকোন যন্ত্রের ক্ষেত্রে প্রযোজ্য হতে পারে যা মানুষের মনের সাথে সম্পর্কিত বৈশিষ্ট্যগুলি প্রদর্শন করে যেমন শেখা এবং সমস্যার সমাধান করা।
# কৃত্রিম বুদ্ধিমত্তার আদর্শ বৈশিষ্ট্য হল এর যৌক্তিক করার ক্ষমতা এবং নির্দিষ্ট লক্ষ্য অর্জনের সর্বোত্তম সুযোগের সাথে কাজ করা।
# কৃত্রিম বুদ্ধিমত্তার একটি উপসেট হল মেশিন লার্নিং (ML), যা নির্দেশ করে যে কম্পিউটার প্রোগ্রামগুলি স্বয়ংক্রিয়ভাবে নতুন ডেটা থেকে শেখার এবং অভিযোজিত হতে পারে।
# গভীর শিক্ষার কৌশলগুলি টেক্সট, চিত্র বা ভিডিওর মতো বিশাল পরিমাণ অনিয়ন্ত্রিত ডেটার শোষণের মাধ্যমে এই স্বয়ংক্রিয় শিক্ষাকে সক্ষম করে।

# %% [markdown]
# ## Token splitting
#
# চাঙ্ক: চাঙ্ক হল বড় কিছু লেখার বা টেক্সট এর অংশ বা ভাগ। এটি সাধারণভাবে টেক্সট স্ট্রিং কে অনুভাগে ভাগ করে ফেলতে ব্যবহৃত হয়, যাতে প্রতিটি অংশের বিশেষ বৈশিষ্ট্য অনুসারে প্রসেসিং করা যায়। একটি চাঙ্ক এর কিছু সাধারণ উদাহরণ হল প্যারাগ্রাফ, অনুচ্ছেদ, অধ্যায়, ইত্যাদি।
#
# টোকেন: একটি টোকেন সাধারণত প্রায় ৪ ক্যারেক্টারের হতে পারে, যা সাধারণত বাক্যের একটি সাধারণ পদ বা শব্দ বা অক্ষর গুচ্ছ হিসাবে ব্যবহৃত হয়।
# উদাহরণস্বরূপ, "বইমেলা", "নারী", "পুরস্কার", "কোডিং" ইত্যাদি টোকেন হতে পারে। এই ধরনের টোকেন সাধারণত বাক্যের অংশ হিসাবে ব্যবহৃত হয়।

# %%
from langchain.text_splitter import TokenTextSplitter

# %%
text_splitter = TokenTextSplitter(chunk_size=1, chunk_overlap=0)

# %%
text1 = """Artificial intelligence (AI) refers to the simulation of human intelligence in machines"""

# %%
text_splitter.split_text(text1)
# Out:
# ['Art',
#  'ificial',
#  ' intelligence',
#  ' (',
#  'AI',
#  ')',
#  ' refers',
#  ' to',
#  ' the',
#  ' simulation',
#  ' of',
#  ' human',
#  ' intelligence',
#  ' in',
#  ' machines']

# %%
text_splitter = TokenTextSplitter(chunk_size=10, chunk_overlap=0)

# %%
text_splitter.split_text(text1)
# Out:
# ['Artificial intelligence (AI) refers to the simulation',
#  ' of human intelligence in machines']

# %% [markdown]
# ## Apply split in our documents

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("English_THE_CREATION_OF_THE_UNIVERSE.pdf")
docs = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,       # প্রতিটি অংশে সর্বাধিক অক্ষরের সংখ্যা
    chunk_overlap=50      # অংশগুলির মধ্যে ওভারল্যাপ করা অক্ষরের সংখ্যা
)

# %%
splits = text_splitter.split_documents(docs)

# %%
len(splits)
# Out:
# 935

# %%
for i, chunk in enumerate(splits):
    print(f"Chunk {i+1}:\n{chunk}\n")
# Out:
# Chunk 1:
# page_content="Now writing under the pen-name of HARUN YAHYA,\nAdnan Oktar was born in Ankara in 1956. Having completed\nhis primary and secondary education in Ankara, he studied fi-\nne arts at Istanbul's Mimar Sinan University and philosophy at\nIstanbul University. Since the 1980s, he has published many bo-\noks on political, scientific, and faith-related issues. Harun Yahya\nis well-known as the author of important works disclosing the\nimposture of evolutionists, their invalid claims, and the dark liai-" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 5}
#
# Chunk 2:
# page_content="sons between Darwinism and such bloody ideologies as fascism\nand communism. \nHarun Yahya's works, translated into 63 different languages,\nconstitute a collection for a total of more than 55,000 pages with\n40,000 illustrations. \nHis pen-name is a composite of the names Harun (Aaron) and\nYahya (John) , in memory of the two esteemed Prophets who fought\nagainst their peoples' lack of faith. The Prophet's seal on his books' co-\nvers is symbolic and is linked to their contents. It represents the" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 5}
#
# Chunk 3:
# page_content='Qur\'an (the Final Scripture) and the  Prophet Muhammad (pbuh), lastof the prophets. Under the guidance of the Qur\'an and the Sunnah (te-achings of the Prophet [saas]), the author makes it his purpose to dis-\nprove each fundamental tenet of irreligious ideologies and to have the\n"last word," so as to completely silence the objections raised\nagainst religion. He uses the seal of the final Prophet (sa-\nas), who attained ultimate wisdom and moral perfecti-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 5}
#
# Chunk 4:
# page_content="on, as a sign of his intention to offer the last word. \nAll of Harun Yahya's works share one single goal:\nto convey the Qur'an's message, encourage readers\nto consider basic faith-related issues such as Allah's\nexistence and unity and the Hereafter; and to expo-\nse irreligious systems' feeble foundations and per-\nverted ideologies. \nHarun Yahya enjoys a wide readership in\nmany countries, from India to America,\nEngland to Indonesia, Poland to Bosnia,\nSpain to Brazil, Malaysia to Italy, France" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 5}
#
# Chunk 5:
# page_content='to Bulgaria and Russia. Some of his books are available in English, French,\nGerman, Spanish, Italian, Portuguese, Urdu, Arabic, Albanian, Chinese, Swahili,Hausa, Dhivehi (spoken in Maldives), Russian, Serbo-Croat (Bosnian), Polish,Malay, Uygur Turkish, Indonesian, Bengali, Danish and Swedish. \nGreatly appreciated all around the world, these works have been instrumen-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 6:
# page_content="tal in many people recovering faith in Allah and gaining deeper insights into the-ir faith. His books' wisdom and sincerity, together with a distinct style that's easyto understand, directly affect anyone who reads them. Those who seriously con-sider these books, can no longer advocate atheism or any other perverted ideo-logy or materialistic philosophy, since these books are characterized by rapid ef-fectiveness, definite results, and irrefutability. Even if they continue to do so, itwill be" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 7:
# page_content='Even if they continue to do so, itwill be only a sentimental insistence, since these books refute such ideologiesfrom their very foundations. All contemporary movements of denial are nowideologically defeated, by means of the books written by Harun Yahya.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 8:
# page_content="This is no doubt a result of the Qur'an's wisdom and lucidity. The author mo-\ndestly intends to serve as a means in humanity's search for Allah's right path. Nomaterial gain is sought in the publication of these works.\nThose who encourage others to read these books, to open their minds and he-\narts and guide them to become more devoted servants of Allah, render an inva-luable service. \nMeanwhile, it would only be a waste of time and energy to propagate other" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 9:
# page_content="books that create confusion in people's minds, lead them into ideological confu-sion, and that clearly have no strong and precise effects in removing the doubtsin people's hearts, as also verified from previous experience. It is impossible forbooks devised to emphasize the author's literary power rather than the noble go-al of saving people from loss of faith, to have such a great effect. Those who do-ubt this can readily see that the sole aim of Harun Yahya's books is to overcomedisbelief and" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 10:
# page_content="Harun Yahya's books is to overcomedisbelief and to disseminate the Qur'an's moral values. The success and impactof this service are manifested in the readers' conviction." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 11:
# page_content='One point should be kept in mind: The main reason for the continuing cruelty,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 12:
# page_content="conflict, and other ordeals endured by the vast majority of people is the ideolo-gical prevalence of disbelief. This can be ended only with the ideological defeatof disbelief and by conveying the wonders of Creation and Qur'anic morality sothat people can live by it. Considering the state of the world today, leading intoa downward spiral of violence, corruption and conflict, clearly this service mustbe provided speedily and effectively, or it may be too late." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 13:
# page_content="In this effort, the books of Harun Yahya assume a leading role. By the will of\nAllah, these books will be a means through which people in the twenty-first cen-tury will attain the peace, justice, and happiness promised in the Qur'an." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 6}
#
# Chunk 14:
# page_content="TO THE READER\n●A special chapter is assigned to the collapse of the theory of evolution because this\ntheory constitutes the basis of all anti-spiritual philosophies. Since Darwinism rejectsthe fact of Creation\n–and therefore, Allah's existence –over the last 150 years it has" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 15:
# page_content="caused many people to abandon their faith or fall into doubt. It is therefore an im-perative service, a very important duty to show everyone that this theory is a decep-tion. Since some readers may find the opportunity to read only one of our books, wethink it appropriate to devote a chapter to summarize this subject. \n●All the author's books explain faith-related issues in light of Qur'anic verses, and in-" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 16:
# page_content="vite readers to learn Allah's words and to live by them. All the subjects concerningAllah's verses are explained so as to leave no doubt or room for questions in the read-er's mind. The books' sincere, plain, and fluent style ensures that everyone of everyage and from every social group can easily understand them. As a result of their ef-fective, lucid narrative, they can be read at one sitting. Even those who rigorously re-ject spirituality are influenced by the facts these books document and" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 17:
# page_content='influenced by the facts these books document and cannot refutethe truthfulness of their contents.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 18:
# page_content='●This and all the other books by the author can be read individually, or discussed in a\ngroup. Readers eager to profit from the books will find discussion very useful, lettingthem relate their reflections and experiences to one another. \n●In addition, it will be a great service to Islam to contribute to the publication and' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 19:
# page_content="reading of these books, written solely for the pleasure of Allah. The author's booksare all extremely convincing. For this reason, to communicate true religion to others,one of the most effective methods is encouraging them to read these books.\n●We hope the reader will look through the reviews of his other books at the back of\nthis book. His rich source material on faith-related issues is very useful, and a plea-sure to read." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 20:
# page_content="●In these books, unlike some other books, you will not find the author's personal\nviews, explanations based on dubious sources, styles that are unobservant of the re-spect and reverence due to sacred subjects, nor hopeless, pessimistic arguments thatcreate doubts in the mind and deviations in the heart." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 7}
#
# Chunk 21:
# page_content='THE\nCREATION \nOF THE\nUNIVERSE\nHARUN YAHYA\n(ADNAN OKTAR)' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 8}
#
# Chunk 22:
# page_content='www.har un ya hya.com - www.har un ya hya.net\nen.harunyahya.tv' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 9}
#
# Chunk 23:
# page_content='INTROD UCTION1 0\nTHE SCIENTIFIC COLLAPSE OF MATER IALISM\nCHAPTER 11 6\nTHE CREAT ION OF THE UNIV ERSE \nFROM NOTHINGN ESS\nCHAPTER 23 2\nTHE E QUILIB RIUM IN THE E XPLOSION\nCHAPTER 34 8\nTHE RH YTHM OF THE ATO MS\nCHAPTER 46 6\nTHE ORDER IN THE SKIES\nCHAPTER 58 2\nTHE BLUE PLANET\nCHAPTER 6 108\nTHE SIGNS  OF CREAT ION IN LIGHT\nCHAPTER 7 130\nTHE SIGNS  OF CREAT ION IN WATER\nCHAPTER 8 150\nTHE SPECIALLY-C REATED E LEMENTS OF LIFE\nCONCLUSI ON1 7 0\nAN APPEAL TO REA SON\nAPPENDIX 178\nTHE E VOLUTION DECEIT' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 10}
#
# Chunk 24:
# page_content='THE SCIENTIFIC\nCOLLAPSE OFMATERIALISM\nMaterialism can no longer claim to be a \nscientific philosophy.\nArthur Koestler, \nthe renowned Social Philosopher1' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 12}
#
# Chunk 25:
# page_content='THE CREATION OF THE UNIVERSE 12\nHow did the endless universe we live in come into being? \nHow did the equilibrium, harmony, and order of this universe develop?How is it that this Earth is such a fit and sheltering place for us to live in?Questions such as these have attracted attention since the dawn of the hu-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 13}
#
# Chunk 26:
# page_content='man race. The conclusion reached by scientists and philosophers searching foranswers with their intellects and common sense is that the structure and orderof this universe are one of the evidences of the existence of Almighty Allah, thesupreme Creator ruling over the whole universe.\nThis is an indisputable truth that we may reach by using our intelligence, con-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 13}
#
# Chunk 27:
# page_content="science and evidences. Allah declares this reality in His holy book, the Qur'an,which He inspired as a guide for humanity fourteen centuries ago. He states thatHe has created the universe when it was not, for a particular purpose, and withall its systems and balances specifically created for human life." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 13}
#
# Chunk 28:
# page_content="Allah invites people to consider this truth in the following verse:Are you stronger in structure or is heaven? He built it. He raised itsvault high and made it level. He darkened its night and brought forthits morning light. After that He smoothed out the earth… (Surat anNaziat: 27-30)\nAllah also states in the Qur'an that a person should see and consider\nall the systems and balances in the universe that have been creat-\ned for him by Allah and derive a lesson from his obser-\nvations:" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 13}
#
# Chunk 29:
# page_content='vations:\nHe has made night and day sub-\nservient to you, and the Sun' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 13}
#
# Chunk 30:
# page_content='and Moon and stars, all subject to His command. There is certainly' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 14}
#
# Chunk 31:
# page_content="signs in that for people who pay heed. (Surat an-Nahl: 12)In yet another verse of the Qur'an, Almighty Allah states as follows:He makes night merge into day and day merge into night, and He hasmade the Sun and Moon subservient, each one running until a speci-fied time. That is Allah, your Lord. The Kingdom is His. Those you callon besides Him have no power over even the smallest speck.(SurahFatir: 13)This plain truth declared by the Qur'an is also confirmed by a number of the" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 14}
#
# Chunk 32:
# page_content='important founders of the modern science of astronomy. Galileo, Kepler, andNewton all recognized that the structure of universe, the order in the solar sys-tem, the laws of physics and their states of equilibrium were all created by Allahand they arrived at that conclusion as a result of their own research and obser-vations.\nMaterialism: A 19th-Century Fallacy\nThe reality of the Creation of which we speak has been ignored or denied' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 14}
#
# Chunk 33:
# page_content='since the earliest times by a particular philosophical point of view. It is called"materialism". This philosophy, which was originally formulated among the an-cient Greeks, has also made an appearance from time to time in other culturesand has been advanced by individuals as well. It holds that matter alone existsand that it has done so for an infinity of time. From these tenets, it falsely claimsthat the universe has also "always" existed and was not created.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 14}
#
# Chunk 34:
# page_content='In addition to their claim that the universe exists in an infinity of time, mate-\nrialists also assert that there is no purpose or aim in the universe. They claim thatall the equilibrium, harmony and order that we see around us are merely theHarun Yahya (Adnan Oktar) 13' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 14}
#
# Chunk 35:
# page_content='THE CREATION OF THE UNIVERSE\nprod-\nuct of coincidence.\nThis "coincidence assertion" is\nalso put forward when the question of\nhow human beings came into being comes up. The\ntheory of evolution, widely referred to as Darwinism, is an-\nother application of materialism to the natural world.\nWe just mentioned that some of the founders of today\'s science were' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 15}
#
# Chunk 36:
# page_content="faithful people who were in agreement that the universe was created andorganized by Allah. In the 19th century, an important change took place inthe attitudes of the scientific world with respect to this matter. Materialismwas deliberately introduced to the agenda of modern science by variousgroups. Because the 19th century's political and social conditions formed agood basis for materialism, the philosophy gained wide acceptance andspread throughout the scientific world." metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 15}
#
# Chunk 37:
# page_content='The findings of modern science however undeniably demonstrate how\nfalse the claims of materialism really are.\nThe Findings of 20th-Century\nScience\nLet us recall the two assertions of materialism\nabout the universe:\nThe universe exists in infinite time and, becauseit has no beginning or end, it was not created.Everything in this universe is merely the result\nof chance and not the product of any intentionalorder, plan, or purpose.\nThose two notions were boldly ad-14' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 15}
#
# Chunk 38:
# page_content='Those two notions were boldly ad-14\nToday\'s science proves the reality of the\nCreation of the universe by Allah, contrary to\nwhat outdated materialist philosophy main-\ntains. Newsweek made "Science Finds God"\nthe cover story of its July 27th 1998 issue.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 15}
#
# Chunk 39:
# page_content='vanced and ardently defended by 19th-century material-\nists, who of course had no recourse other than to dependupon the limited and unsophisticated scientific knowledgeof their day. Both have been utterly refuted by the discoveriesof 20th-century science.\nThe first to be laid in the grave was the notion of the universe existing in in-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 40:
# page_content='finite time. Since the 1920s, there has been mounting evidence this cannot be true.Scientists are now certain that the universe came into being from nothingness asthe result of an unimaginably huge explosion, known as the "Big Bang" . In oth-\ner words, the universe came into being–or rather, it was created by Allah.\nThe 20th century has also witnessed the demolition of the second claim of ma-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 41:
# page_content='terialism: that everything in the universe is the result of chance and not Creation.Research conducted since the 1960s consistently demonstrates that all the physi-cal equilibriums of the universe in general and of our world in particularly are in-tricately created to make life possible. As this research deepened, it was discov-ered each and every one of the laws of physics, chemistry, and biology, of thefundamental forces such as gravity and electromagnetism, and of the details of thestructure' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 42:
# page_content='and of the details of thestructure of atoms and the elements of the universe has been precisely tailored sothat human beings may live. Scientists today call this extraordinary order the "an-thropic principle". This is the principle that every detail in the universe has beencarefully arranged to make human life possible.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 43:
# page_content='To sum up, the philosophy called materialism has been utterly refuted by to-\nday\'s science. From its position as the dominant scientific view of the 19th centu-ry, materialism collapsed into fiction in the 20th.\nHow could it have been otherwise? As Allah indicates "We did not create\nheaven and earth and everything between them to no purpose. That is theopinion of those who are unbelievers." (Surah Sad: 27) it is wrong to suppose' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 44:
# page_content="that the universe was created in vain. A philosophy so utterly flawed as material-ism and systems based on it were doomed to failure from the very beginning.\nCreation is a fact. In this book we will be examining the evidence for this fact.\nWe will see how materialism has collapsed in the face of today's science and al-so witness how wonderfully and perfectly the universe has been created by Allah.Harun Yahya (Adnan Oktar)" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 16}
#
# Chunk 45:
# page_content='THE CREATION\nOF THE UNIVERSE FROMNOTHINGNESS\nIn its standard form, the big bang theory assumes\nthat all parts of the universe began expanding si-\nmultaneously. But how could all the different parts of\nthe universe synchronize the beginning of their ex-\npansion? Who gave the command? \nAndre Linde, Professor of Cosmology2' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 18}
#
# Chunk 46:
# page_content='THE CREATION OF THE UNIVERSE\nAcentury ago, the Creation of the universe was a concept that as-\ntronomers as a rule ignored. The reason was the general accep-tance of the idea that the universe existed in infinite time.\nExamining the universe, scientists supposed that it was just a conglomera-tion of matter and imagined that it had no beginning. There was no mo-ment of "Creation"–a moment when the universe and everything in it cameinto being.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 47:
# page_content='This idea of "eternal existence" fit in well with European notions stem-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 48:
# page_content='ming from the philosophy of materialism.This philosophy, originally advanced inthe world of the ancient Greeks, held thatmatter was the only thing that existed inthe universe and the universe existed ininfinite time and will exist endlessly. Thisphilosophy survived in different formsduring Roman times but in the LateRoman Empire and after, materialismwent into decline as a result of the influ-ence of the Catholic church and Christianfaith. It was after Renaissance that mate-rialism began to' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 49:
# page_content='was after Renaissance that mate-rialism began to gain broad acceptanceamong European scholars and scientists,largely because of their devotion to an-cient Greek philosophy.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 50:
# page_content='It was Immanuel Kant who, during the' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 51:
# page_content="European Enlightenment, reasserted anddefended materialism. Kant declared that the universe exists for all timeand that every probability, however unlikely, should be regarded as possi-ble. Kant's followers continued to defend his idea of an infinite universealong with materialism. By the beginning of 19th century, the idea that theuniverse had no beginning–that there was never any moment at which itwas created–became widely accepted. It was carried into the 20th century18" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 52:
# page_content='The German philosopher Immanuel\nKant was the first person to ad-\nvance the assertion of "the infinite\nuniverse" in the New Age. Scientific\ndiscoveries, however, invalidated\nKant\'s assertion.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 19}
#
# Chunk 53:
# page_content='through the works of dialectical materialists such as Karl Marx and Friedrich\nEngels.\nThis notion of an infinite universe fit in very well with atheism. It is not' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 54:
# page_content='hard to see why. To hold that the universe had a beginning could implythat it was created and that, of course requires a creator–that is, Allah. Itwas much more convenient and safer to circumvent the issue by puttingforward the idea that "the universe exists for eternity", even though therewas not the slightest scientific basis for making such a claim. GeorgesPolitzer, who espoused and defended this idea in his books published inthe early 20th century, was an ardent champion of both Marxism and' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 55:
# page_content='was an ardent champion of both Marxism and ma-terialism.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 56:
# page_content='Putting his trust in the alleged validity of the "infinite universe" model,\nPolitzer opposed the idea of Creation in his book Principes Fondamentaux\nde Philosophie when he wrote:' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 57:
# page_content='de Philosophie when he wrote:\nThe universe was not a created object, if it were, then it would have tobe created instantaneously by God and brought into existence fromnothing. To admit creation, one has to admit, in the first place, the ex-istence of a moment when the universe did not exist, and that some-thing came out of nothingness. This is something to which science cannot accede. \n3\nPolitzer supposed that science was on his side in his defense of the idea' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 58:
# page_content='of an infinite universe. In fact, science was to prove that the universe in-deed had a beginning. And just as Politzer himself declared, if there isCreation then there must also be a creator.\nThe Expansion of Universe and the Discovery of the\nBig Bang\nThe 1920s were important years in the development of modern astron-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 59:
# page_content="omy. In 1922, the Russian physicist Alexandra Friedman produced compu-tations showing that the structure of the universe was not static and thateven a tiny impulse might be sufficient to cause the whole structure to ex-pand or contract according to Einstein's Theory of Relativity. GeorgeHarun Yahya (Adnan Oktar) 19" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 20}
#
# Chunk 60:
# page_content='THE CREATION OF THE UNIVERSE\nLemaitre was the first to recognize\nwhat Friedman\'s work meant.Based on these computations, theBelgian astronomer Lemaitre de-clared that the universe had a be-ginning and that it was expandingas a result of something that had\ntriggered it. He also stated that the rate of radiation could be used as a mea-sure of the aftermath of that "something".\nThe theoretical musings of these two scientists did not attract much at-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 61:
# page_content='tention and probably would have been ignored except for new observa-tional evidence that rocked the scientific world in 1929. That year theAmerican astronomer Edwin Hubble, working at the California MountWilson observatory, made one of the most important discoveries in the his-tory of astronomy. Observing a number of stars through his huge telescope,he discovered that their light was shifted towards the red end of the spec-trum and, crucially, that this shift was directly related to the' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 62:
# page_content='that this shift was directly related to the distance of thestars from Earth. This discovery shook the very basis of the universe mod-el held until then.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 63:
# page_content='According to the recognized rules of physics, the spectra of light beams' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 64:
# page_content="travelling towards the point of observation tend towards violet while thespectra of light beams moving away from the point of observation tend to-wards red. (Just like the fading of a train's whistle as it moves away fromthe observer) Hubble's observation showed that according to this law, theheavenly bodies were moving away from us. Before long, Hubble madeanother important discovery; The stars weren't just racing away from Earth;20\nEdwin Hubble discovered that the uni-" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 65:
# page_content='Edwin Hubble discovered that the uni-\nverse was expanding. Eventually hefound evidence of the "the Big Bang", acataclysmic event whose discoveryforced scientists to abandon the notionof an infinite and eternal universe.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 21}
#
# Chunk 66:
# page_content='they were racing away from each other as well. The only conclusion that\ncould be derived from a universe where everything moves away fromeverything else is that the universe constantly "expands".\nHubble had found observational evidence for something that George\nLemaitre had anticipated a short while ago and one of the most importantminds of our age had recognized almost fifteen years earlier. In 1915,Albert Einstein had concluded that the universe could not be static be-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 67:
# page_content='cause of calculations based on his recently-discovered theory of relativity(thus anticipating the conclusions of Friedman and Lemaitre). Shocked byhis findings, Einstein added a "cosmological constant" to his equations inorder to make the answer compatible with the atheist view, because as-tronomers assured him that the universe was static and there was no otherway to make his equations match such a model. Years later, Einstein wasto admit that his cosmological constant was the biggest mistake' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 68:
# page_content='his cosmological constant was the biggest mistake of his ca-reer.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 69:
# page_content="Hubble's discovery that the universe was expanding led to the emer-" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 70:
# page_content='gence of another model that needed no fiddling around with to make theequations work right. If the universe was getting bigger as time advanced,going back in time meant that it was getting smaller; and if one went backfar enough, everything would shrink and converge at a single point. Theconclusion to be derived from this model was that at some time, all thematter in the universe was compacted in a single point-mass that had "ze-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 71:
# page_content='ro volume" because of its immense gravitational force. Our universe came\ninto being as the result of the explosion of this point-mass that had zerovolume. This explosion has come to be called the "the Big Bang" and its\nexistence has repeatedly been confirmed by observational evidence.\nThere was another truth that the Big Bang pointed to. To say that some-\nthing has zero volume is tantamount to saying that it is "nothing". The\nwhole universe was created from this "nothing" . And furthermore this' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 72:
# page_content='universe had a beginning, contrary to the view of materialism, which holdsthat "the universe has existed for eternity".Harun Yahya (Adnan Oktar) 21' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 22}
#
# Chunk 73:
# page_content='THE CREATION OF THE UNIVERSE\nThe " Steady -state" Hypothesis\nThe Big Bang theory quickly gained wide acceptance in the scientific' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 74:
# page_content='world due to the clear-cut evidence for it. Nevertheless astronomers whofavored materialism and adhered to the idea of an infinite universe that ma-terialism seemingly demanded held out against the Big Bang in their strug-gle to uphold a fundamental tenet of their ideology. The reason was madeclear by the English astronomer Arthur Eddington, who said"Philosophically, the notion of an abrupt beginning to the present order ofNature is repugnant to me".\n4' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 75:
# page_content='4\nAnother astronomer who opposed the Big Bang theory was Fred Hoyle.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 76:
# page_content='Around the middle of the 20th century he came up with a new model,which he called "steady-state", that was an extension of the 19th century\'sidea of an infinite universe. Accepting the incontrovertible evidence thatthe universe was expanding, he proposed that the universe was infinite inboth dimension and time. According to this model, as the universe ex-panded new matter was continuously coming into existence by itself in justthe right amount to keep the universe in a "steady state". With the' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 77:
# page_content='keep the universe in a "steady state". With the sole vis-ible aim of supporting the dogma of "matter existed in infinite time", whichis the basis of the materialist philosophy, this theory was totally at variancewith the "Big Bang theory", which defends that the universe had a begin-ning. Supporters of Hoyle\'s steady state theory remained adamantly op-posed to the Big Bang for years. Science, however, was working againstthem.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 78:
# page_content='The Triumph of the Big Bang\nIn 1948, George Gamov carried George Lemaitre\'s cal-\nculations several steps further and came up with a new\nidea concerning the Big Bang. If the universe was formed\nin a sudden, cataclysmic explosion, there ought to be a22\nSir Arthur Eddington\'s statement that "the\nnotion of an abrupt beginning to the pre-sent order of nature was repugnant to him"was an admission of the discomfort thatthe Big Bang caused for materialists.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 23}
#
# Chunk 79:
# page_content='definite amount of radiation left over from that explosion. This radiation\nshould be detectable and, furthermore, it should be uniform throughout theuniverse. \nWithin two decades, observational proof of Gamov\'s conjecture was\nforthcoming. In 1965, two researchers by the name of Arno Penzias andRobert Wilson discovered a form of radiation hitherto unnoticed. Called"cosmic background radiation" , it was unlike anything coming from' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 80:
# page_content='anywhere else in the universe for it was extraordinarily uniform. It was nei-ther localized nor did it have a defi-nite source; instead, it was distributedequally everywhere. It was soon real-ized that this radiation was the echoof the Big Bang, still reverberatingsince the first moments of that greatexplosion. Gamov had been spot-onfor the frequency of the radiation wasnearly the same value that scientistshad predicted it would be. Penziasand Wilson were awarded a Nobelprize for their' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 81:
# page_content='Wilson were awarded a Nobelprize for their discovery.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 82:
# page_content='In 1989, George Smoot and his' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 83:
# page_content='NASA team sent a satellite into space. Called the "Cosmic BackgroundEmission Explorer" (COBE), it took only eight minutes for the sensitive in-struments on board the satellite to detect and confirm the levels of radia-tion reported by Penzias and Wilson. These results conclusively demon-strated the existence of the hot, dense form remaining from the explosionout of which the universe came into being. Most scientists acknowledgedthat COBE had successfully captured the remnants of the Big Bang.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 84:
# page_content='More evidence for the Big Bang was forthcoming. One piece had to do\nwith the relative amounts of hydrogen and helium in the universe.Observations indicated that the mix of these two elements in the universewas in accord with theoretical calculations of what should have been re-mained after the Big Bang. That drove another stake into the heart of theHarun Yahya (Adnan Oktar) 23\nThe cosmic background radiation discov-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 85:
# page_content='The cosmic background radiation discov-\nered by Penzias and Wilson is regardedas incontrovertible evidence of the BigBang by the scientific world.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 24}
#
# Chunk 86:
# page_content='THE CREATION OF THE UNIVERSE\nsteady state theory because if the universe had existed for eternity and nev-\ner had a beginning, all of its hydrogen should have been burned into heli-um.\nConfronted by such evidence, the Big Bang gained the near-complete\napproval of the scientific world. In an article in its October 1994 issue,Scientific American noted that the Big Bang model was the only one that\ncould account for the constant expansion of the universe and for other ob-servational results.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 87:
# page_content='Defending the steady-state theory alongside Fred Hoyle for years,\nDennis Sciama described the final position they had reached after all theevidence for the Big Bang theory was revealed:' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 88:
# page_content='There was at that time a somewhat acrimonious debate between someof the proponents of the steady state theory and observers who were test-ing it and, I think, hoping to disprove it. I played a very minor part atthat time because I was a supporter of the steady state theory, not in thesense that I believed that it had to be true, but in that I found it so at-tractive I wanted it to be true. When hostile observational evidence be-came to come in, Fred Hoyle took a leading part in trying to' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 89:
# page_content='in, Fred Hoyle took a leading part in trying to counterthis evidence, and I played a small part at the side, also making sug-gestions as to how the hostile evidence could be answered. But as thatevidence piled up, it became more and more evident that the game wasup, and that one had to abandon the steady state theory.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 90:
# page_content='5\nWho Created the Universe From Nothing?\nWith this triumph of the Big Bang, the thesis of an "infinite universe",\nwhich forms the basis of materialist dogma, was tossed onto the scrap-heapof history. But for materialists it also raised a couple of inconvenient ques-tions: What existed before the Big Bang? And what force could have caused\nthe great explosion that resulted in a universe that did not exist before?\nMaterialists like Arthur Eddington recognized that the answers to these' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 91:
# page_content='questions could point to the "fact of Creation" and that they did not like.Anthony Flew, a philosopher who used to be an atheist but later acknowl-24' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 25}
#
# Chunk 92:
# page_content='edged the fact of Creation, had commented on this point:\nNotoriously, confession is good for the soul. I will therefore begin byconfessing that the Stratonician atheist has to be embarrassed by\nthe contemporary cosmological consensus. For it seems that the\ncosmologists are providing a scientific proof of what St. Thomas con-tended could not be proved philosophically; namely, that the universehad a beginning. \n6\nMany scientists who do not force themselves to be atheists accept and' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 93:
# page_content='favor the existence of Allah, Who has an infinite power. For instance, theAmerican astrophysicist Hugh Ross states that there is a Creator of the uni-verse, Who is above all physical dimensions as:' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 94:
# page_content="By definition, time is that dimension in which cause-and-effect phe-nomena take place. No time, no cause and effect. If time's beginning isconcurrent with the beginning of the universe, as the space-time theo-rem says, then the cause of the universe must be some entity operatingin a time dimension completely independent of and pre-existent to thetime dimension of the cosmos. …It tells us that the Creator is transcen-dent, operating beyond the dimensional limits of the universe. It tells usthat" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 95:
# page_content='limits of the universe. It tells usthat God is not the universe itself, nor is God contained within the uni-verse.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 96:
# page_content='7\nObjections to the Fact of Creation and Why They\nare Flawed\nIt is patently obvious that the Big Bang means the Creation of the uni-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 97:
# page_content='verse out of nothing and this is surely evidence of willful Creation.Regarding this fact, some materialist astronomers and physicists have triedto advance alternative explanations to oppose this reality. Mention has al-ready been made of the steady state theory and it was pointed out it wasclung to, by those who were uncomfortable with the notion of "Creationfrom nothingness", despite all the evidence to the contrary in an attempt toshore up their philosophy.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 98:
# page_content='There are also a number of models that have been advanced by mate-Harun Yahya (Adnan Oktar) 25' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 26}
#
# Chunk 99:
# page_content='THE CREATION OF THE UNIVERSE\nrialists who accept the Big Bang theory but try to exorcise it of the notion\nof Creation. One of these is the "oscillating" universe model; another is the"quantum model of universe". Let us examine these theories and see whythey are invalid.\nThe oscillating universe model was advanced by the astronomers' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 100:
# page_content='who disliked the idea the Big Bang was the beginning of the universe. Inthis model, it is claimed that the present expansion of the universe willeventually be reversed at some point and begin to contract. This contrac-tion will cause everything to collapse into a single point that will then ex-plode again, initiating a new round of expansion. This process, they say, isrepeated infinitely in time. This model also holds that the universe has ex-perienced this transformation an infinite number of' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 101:
# page_content='this transformation an infinite number of times already and thatit will continue to do so forever. In other words, the universe exists for eter-nity but it expands and collapses at different intervals with a huge explo-sion punctuating each cycle. The universe we live in is just one of those in-finite universes going through the same cycle.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 102:
# page_content='This is nothing but a feeble attempt to accommodate the fact of the Big' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 103:
# page_content='Bang to notions about an infinite universe. The proposed scenario is un-supported by the results of scientific research over the last 15-20 years,which show that it is impossible for such an "oscillating" universe idea tocome into being. Furthermore the laws of physics offer no reason why acontracting universe should explode again after collapsing into a singlepoint: it ought to stay just as it is. Nor do they offer a reason why an ex-panding universe should ever begin to contract in the first' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 104:
# page_content='should ever begin to contract in the first place.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 105:
# page_content='8\nEven if we allow that there is some mechanism by which this cycle of' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 106:
# page_content='contraction-explosion-expansion does take place, the crucial point is thatthis cycle cannot go on for ever, as is claimed. Calculations for this modelshow that each universe will transfer an amount of entropy to its succes-sor. In other words, the amount of useful energy available becomes lesseach time and every "opening" universe will open more slowly and have alarger diameter. This will cause a much smaller universe to form the nexttime around and so on, eventually petering out into nothing.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 107:
# page_content='and so on, eventually petering out into nothing. Even if "openand close" universes can exist, they cannot endure for eternity. At some26' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 27}
#
# Chunk 108:
# page_content='point it becomes necessary for "something" to be created from "nothing".9\nPut briefly, the "oscillating" universe model is a hopeless fantasy whose\nphysical reality is impossible.\nThe "quantum model of universe" is another attempt to purge the Big' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 109:
# page_content='Bang of its creationist implications. Supporters of this model base it on theobservations of quantum (subatomic) physics. In quantum physics, it is tobe observed that subatomic particles appear and disappear spontaneouslyin a vacuum. Interpreting this observation as "matter can originate at quan-tum level, this is a property pertaining to matter", some physicists try to ex-plain the origination of matter from non-existence during the Creation ofthe universe as a "property pertaining to matter"' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 110:
# page_content='universe as a "property pertaining to matter" and present it as a part oflaws of nature. In this model, our universe is interpreted as a subatomicparticle in a bigger one.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 111:
# page_content='However this syllogism is definitely out of question and in any case can-\nnot explain how the universe came into being. William Lane Craig, the au-thor of The Big Bang: Theism and Atheism explains why:' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 112:
# page_content='A quantum mechanical vacuum spawning material particles is farfrom the ordinary idea of a "vacuum" (meaning nothing). Rather, aquantum vacuum is a sea of continually forming and dissolving par-ticles, which borrow energy from the vacuum for their brief existence.This is not "nothing," and hence, material particles do not come intobeing out of nothing.\n10\nSo in quantum physics, matter "does not exist when it was not before".' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 113:
# page_content='What happens is that ambient energy suddenly becomes matter and just assuddenly disappears becoming energy again. In short, there is no conditionof "existence from nothingness" as is claimed.\nIn physics, no less than in other branches of the sciences, there are athe-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 28}
#
# Chunk 114:
# ...
#
# Chunk 905:
# page_content="Nature , vol. 373, 1995, p. 470\n53. Michael Denton, Nature's Destiny , p.\n26254. F. Press, R. Siever, \nEarth , New York: W.\nH. Freeman, 1986, p. 255. See. Harun Yahya, \nThe Evolution Deceit:\nThe Scientific Collapse of Darwinism and Its\nIdeological Background , İstanbul, 1998.\n56. Michael Denton, Nature's Destiny , p 106\n57. F. Press, R. Siever, Earth , New York: W.\nH. Freeman, 1986, p 458. F. Press, R. Siever, \nEarth , New York: W.\nH. Freeman, 1986, p 459. F. Press, R. Siever," metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 206}
#
# Chunk 906:
# page_content="H. Freeman, 1986, p 459. F. Press, R. Siever, \nEarth , New York: W.\nH. Freeman, 1986, p 460. Michael Denton, \nNature's Destiny , p.121\n61. James J. Lovelock, Gaia, Oxford:\nOxford University Press, 1987, p.7162. Michael Denton, \nNature's Destiny , p 127\n63. Michael Denton, Nature's Destiny , p 128\n64. Hugh Ross, The Fingerprint of God:\nRecent Scientific Discoveries Reval the\nUnmistakable Identity of the Creator ,\nOranga, California, Promise Publishing,1991, p 129-13265. Ian M. Campbell," metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 206}
#
# Chunk 907:
# page_content='Energy and the\nAtmosphere , London: Wiley, 1977, p.1-2\n66. Ian M. Campbell, Energy and the\nAtmosphere , p.1-2\n67. George Wald, "Life and Light", Scientific\nAmerican , 1959, vol. 201, p.92-108\n68. The near infrared range occupies therays which extends from 0.70 micron, wherevisible light ends, to 1.50 micron. 69. This narrow range occupies the ultravio-let rays between 0.29 micron and 0.32 mi-cron.70. George Greenstein, \nThe Symbiotic\nUniverse , p 96Harun Yahya (Adnan Oktar) 205' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 206}
#
# Chunk 908:
# page_content='THE CREATION OF THE UNIVERSE\n71. George Greenstein, The Symbiotic\nUniverse, p.96-7\n72. This chain reaction taking place in theeye is actually much more complicated. Thelight reaching the eye passes through thelens and falls upon the retina in the back.When light first strikes the retina a photoninteracts with a molecule called 11-\ncis-reti-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 909:
# page_content="nal. The change in the shape of the retinalmolecule forces a change in the shape ofthe protein, rhodopsin, to which the retinalis tightly bound. The protein's metamorpho-sis alters its behaviour. Now calledmetarhodopsin II, the protein sticks to an-other protein, called transducin. Beforebumping into metarhodopsin II, transducinhad tightly bound a small molecule calledGDP. But when transducin interacts withmetarhodopsin II, the GDP falls off, and amolecule called GTP binds to transducin. Now," metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 910:
# page_content='amolecule called GTP binds to transducin. Now, two proteins and one chemical mole-cule are bound to one another and it iscalled GTP-transducin-metarhodopsinII. Itnow binds to a protein called phosphodi-esterase. When attached to metarhodopsinII and its entourage, the phosphodiesteraseacquires the chemical ability to "cut" a mol-ecule called cGMP. Initially there are a lot ofcGMP molecules in the cell, but the phos-phodiesterase lowers its concentration, justas a pulled plug lowers the water' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 911:
# page_content='justas a pulled plug lowers the water level in abathtub.Another protein that binds cGMP is calledan ion channel. It acts as a gateway thatregulates the number of sodium ions in thecell. Normally the ion channel allows sodiumions to flow into the cell, while a separateprotein actively pumps them out again. Thedual action of the ion channel and pumpkeeps the level of sodium ions in the cellwithin a narrow range. When the amount of cGMP is reduced be-cause of cleavage by the phosphodi-esterase,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 912:
# page_content='be-cause of cleavage by the phosphodi-esterase, the ion channel closes, causingthe cellular concentration of positivelycharged sodium ions to be reduced. Thiscauses an imbalance of charge across thecell membrane that, finally, causes a currentto be transmitted down the optic nerve to' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 913:
# page_content="the brain. The result, when interpreted bythe brain, is vision. (Quoted from MichaelBehe, Darwin's Black Box, New York: FreePress, 1996, pp. 18-21).This is actually a very brief and simplifiedversion of how we see. If the events devel-oped like this, we would never be able tosee. If the reactions mentioned above werethe only ones that operated in the cell, thesupply of 11-\ncis-retinal, cGMP, and sodium" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 914:
# page_content="cis-retinal, cGMP, and sodium\nions would quickly be depleted. There aremany mechanisms that would restore thecells to their original state. The reactions described above is far frombeing a complete biochemical explanationof seeing and they are only summarized.However, even what has been related abovesuggests that seeing is a very complicatedand perfect mechanism which can nevercome about by evolution. 73. Michael Denton, \nNature's Destiny , p 62,\n6974. Michael Denton, \nNature's Destiny , p 55" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 915:
# page_content="6974. Michael Denton, \nNature's Destiny , p 55\n75. Encyclopaedia Britannica , 1994, 15th\ned., volume 18, p. 20376. John Ray, \nThe Wisdom of God\nManifested in the Word of Creation , 1701;\nMichael Denton, Nature's Destiny, p. 7377. Lawrence Henderson, \nThe Fitness of the\nEnvironment , Boston: Beacon Press, 1958," metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 916:
# page_content='Foreword.78. The latent heat is the heat which doesnot change the heat of water but enables itto change it from solid state to liquid stateor from liquid state to gas state. When yougive heat to ice to melt it, the ice reaches to0oC and no increase in heat occurs even ifyou continue to heat it. Yet, it is no longerice; it dissolves and becomes water. Thisheat, which is needed to convert the solidstate into the liquid state despite causing nodifference in temperature is "latent" heat. 79' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 917:
# page_content='nodifference in temperature is "latent" heat. 79 Lawrence Henderson,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 918:
# page_content="The Fitness of the\nEnvironment , Boston: Beacon Press, 1958,\np. 10580. Michael Denton, \nNature's Destiny , p. 32\n81. Harold J. Morowitz, Cosmic Joy and206" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 207}
#
# Chunk 919:
# page_content='Local Pain , New York: Scribner, 1987, p.\n152-15382. Michael Denton, \nNature\'s Destiny , p. 33\n83. Michael Denton, Nature\'s Destiny , p. 35-\n3684. "Science Finds God", \nNewsweek , 27\nJuly 1998 85. Fred Hoyle, \nReligion and the Scientists ,\nLondon: SCM, 1959; M. A. Corey, The\nNatural History of Creation , Maryland:\nUniversity Press of America, 1995, p. 34186. David Burnie, \nLife, Eyewitess Science ,\nLondon: Dorling Kindersley, 1996, p. 887. Nevil V. Sidgwick, \nThe Chemical' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 920:
# page_content='The Chemical\nElements and Their Compounds , vol 1.\nOxford: Oxford University Press, 1950, p.49088. Nevil V. Sidgwick, \nThe Chemical\nElements and Their Compounds , vol 1., p.\n49089. J. B. S. Haldane, "The Origin of Life",\nNew Biology, 1954, vol. 16, p. 12\n90. Michael Denton, Nature\'s Destiny , p.\n115-11691. Lawrence Henderson, \nThe Fitness of the\nEnvironment , Boston: Beacon Press, 1958,\np. 247-4892. L. L. Ingraham, "Enzymic Activation ofOxygen", \nComprehensive Biochemistry, (ed.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 921:
# page_content='M. Florkin, E. H. Stotz), Amsterdam:Elsevier, vol. 14, p. 42493. The question of how the complicatedenzyme system enabling oxygen intake bythe respiratory system emerged is one ofthe questions the theory of evolution fails toexplain. This system has an irreduciblecomplexity, in other words, the system cannot function unless all of its componentsfunction perfectly. For this reason, it is un-likely to say that the system developed fromthe simple form to the more complex, asevolution suggests.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 922:
# page_content='form to the more complex, asevolution suggests. Prof. Ali Demirsoy, a bi-ologist from Ankara Hacettepe Universityand a prominent advocate of the theory ofevolution in Turkey, makes the followingconfession about this subject: "However, there is a major problem here.Mitochondria use a fixed number of en-' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 923:
# page_content='zymes during the process of breaking (withoxygen). The absence of only one of theseenzymes stops the functioning of the wholesystem. Besides, energy gain with oxygendoes not seem to be a system which canproceed step by step. Only the completesystem performs its function. That is why,instead of the step by step development towhich we have adhered so far as a princi-ple, we feel the urge to embrace the sug-gestion that, all the enzymes (Krebs en-zyme) needed to perform the reactions ofthe' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 924:
# page_content='en-zyme) needed to perform the reactions ofthe mitochondria entered a cell all at onceby coincidence or, were formed in that cellall at once. That is merely because thosesystems failing to use oxygen fully, in otherwords, those systems remaining in the inter-mediate level would disappear as soon asthey react with oxygen." (Ali Demirsoy, TheBasic Laws of Life: General Zoology,Volume 1, Section 1, Ankara, 1998, p.578) While the probability of the formation of onlyone of the enzymes (special' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 925:
# page_content='the formation of onlyone of the enzymes (special proteins) Prof.Demirsoy mentions above, saying "we haveto accept that they formed all of a suddenby coincidence" is 1 over 10950, it is cer-tainly unreasonable to put forward thatmany enzymes of that sort formed by coin-cidence94. Nevil V. Sidgwick,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 926:
# page_content='The Chemical\nElements and Their Compounds , vol 1.\nOxford: Oxford University Press, 1950, p.49095. Michael Denton, \nNature\'s Destiny , p.\n122-12396. Irwin Fridovich, "Oxygen Radicals,Hydrogen Peroxide, and Oxygen Toxicity",\nFree Radicals in Biology , (ed. W. A. Pryor),\nNew York: Academic Press, 1976, p. 239-24097. J. J. R. Fraústo da Silva, R. J. P.Williams, \nThe Biological Chemistry of the\nElements , Oxford: Oxford University Press,\np. 3-498. J. J. R. Fraústo da Silva, R. J. P.Williams,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 927:
# page_content='The Biological Chemistry of theHarun Yahya (Adnan Oktar) 207' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 208}
#
# Chunk 928:
# page_content="THE CREATION OF THE UNIVERSE 208\nElements , p. 5\n99. Michael Denton, Nature's Destiny , p. 79-\n85100. Jeremy Rifkin, \nAlgeny , New York: The\nViking Press, 1983, p. 114101. Robert Shapiro, \nOrigins: A Sceptics\nGuide to the Creation of Life on Earth , New\nYork, Summit Books, 1986. p.127102. Fred Hoyle, Chandra Wickramasinghe,\nEvolution from Space , New York, Simon &\nSchuster, 1984, p. 148103. Fred Hoyle, Chandra Wickramasinghe,\nEvolution from Space , p. 130" metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 929:
# page_content='Evolution from Space , p. 130\n104. Michael Behe, Darwin\'s Black Box: The\nBiochemical Challenge to Evolution , New\nYork, The Free Press, 1996, p. 252-53105. Colin Patterson, "Evolution andCreationism", Speech at the AmericanMuseum of Natural History, New York(November 5,1981); Henry Morris, \nThat Their\nWords May Be Used Against Them , AR:\nMaster Books, 1997, s. 128106. Sidney Fox, Klaus Dose, \nMolecular\nEvolution and The Origin of Life , W. H.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 930:
# page_content='Evolution and The Origin of Life , W. H.\nFreeman and Company, San Francisco,1972, p. 4.107. Alexander I. Oparin, \nOrigin of Life ,\nDover Publications, NewYork, 1936, 1953(reprint), p. 196.108. "New Evidence on Evolution of EarlyAtmosphere and Life," \nBulletin of the\nAmerican Meteorological Society , vol 63,\nNovember 1982, 1328-1330. 109. Stanley Miller, \nMolecular Evolution of\nLife: Current Status of the Prebiotic\nSynthesis of Small Molecules , 1986, p. 7.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 931:
# page_content='Synthesis of Small Molecules , 1986, p. 7.\n110. Jeffrey Bada, Earth , February 1998, p.\n40.111. Leslie E. Orgel, "The Origin of Life onEarth," \nScientific American , vol. 271,\nOctober 1994, p. 78.112. Charles Darwin, \nThe Origin of Species\nby Means of Natural Selection , The Modern\nLibrary, New York, p. 127.113. Charles Darwin, \nThe Origin of Species:\nA Facsimile of the First Edition , Harvard\nUniversity Press, 1964, p. 184.114. B. G. Ranganathan, Origins? ,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 932:
# page_content='Pennsylvania: The Banner of Truth Trust,1988, p. 7.115. Charles Darwin, \nThe Origin of Species:\nA Facsimile of the First Edition , p. 179.\n116. Charles Darwin, The Origin of Species ,\np. 172.117. Derek A. Ager, "The Nature of theFossil Record," \nProceedings of the British\nGeological Association , vol 87, 1976, p.\n133.118. Douglas J. Futuyma, \nScience on Trial ,\nPantheon Books, New York, 1983, p. 197.119. Solly Zuckerman, \nBeyond The Ivory\nTower , Toplinger Publications, New York,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 933:
# page_content='Tower , Toplinger Publications, New York,\n1970, 75-14; Charles E. Oxnard, "The Placeof Australopithecines in Human Evolution:Grounds for Doubt", \nNature , vol 258, 389.\n120. "Could science be brought to an endby scientists\' belief that they have final an-swers or by society\'s reluctance to pay thebills?" \nScientific American , December 1992,\np. 20.121. Alan Walker, \nScience , vol. 207, 7\nMarch 1980, p. 1103; A. J. Kelso, Physical\nAntropology , 1st ed., J. B. Lipincott Co.,' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 934:
# page_content='Antropology , 1st ed., J. B. Lipincott Co.,\nNew York, 1970, p. 221; M. D. Leakey,\nOlduvai Gorge , vol. 3, Cambridge University\nPress, Cambridge, 1971, p. 272.122. Jeffrey Kluger, "Not So Extinct AfterAll: The Primitive Homo Erectus May HaveSurvived Long Enough To Coexist WithModern Humans," \nTime , 23 December\n1996.123. S. J. Gould, \nNatural History , vol. 85,\n1976, p. 30.124. Solly Zuckerman, \nBeyond The Ivory\nTower , p. 19.\n125. Richard Lewontin, "The Demon-Haunted World,"' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
#
# Chunk 935:
# page_content='The New York Review of\nBooks , January 9, 1997, p. 28.\n126. Malcolm Muggeridge, The End of\nChristendom , Grand Rapids: Eerdmans,\n1980, p. 43.' metadata={'source': 'English_THE_CREATION_OF_THE_UNIVERSE.pdf', 'page': 209}
